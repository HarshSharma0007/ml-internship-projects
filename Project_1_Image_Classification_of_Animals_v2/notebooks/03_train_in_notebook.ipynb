# %% [markdown]
# ### **Launch MLflow UI**

# %% [markdown]
# Instead of launching MLflow from inside the notebook, just open a terminal (VSCode, JupyterLab, or system terminal) and run:
# ```
# mlflow ui --port 5050
# ```
# - Then open http://localhost:5050 in your browser.
#
# - Now your notebook can focus on executing the actual training cells without being blocked by the UI process.

# %% [markdown]
# ### **Trigger Training with Runtime**

# %%
# %cd .. 
# for working in the root directory
# Out:
# c:\Users\DELL\Documents\GitHub\ml-internship-projects\Project_1_Image_Classification_of_Animals_v2
# C:\Users\DELL\AppData\Roaming\Python\Python312\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import time
start = time.time()

# !python -m src.train

print(f"✅ Training completed in {time.time() - start:.2f} seconds")
# Out:
# 🔁 Epoch 1/20
# Train Loss: 2.6783, Acc: 0.1088
# Val   Loss: 2.4559, Acc: 0.2397
# 📦 Saved new best model to: c:\Users\DELL\Documents\GitHub\ml-internship-projects\Project_1_Image_Classification_of_Animals_v2\models\resnet18_20250702_155758.pt
#
# 🔁 Epoch 2/20
# Train Loss: 2.3913, Acc: 0.2934
# Val   Loss: 2.1921, Acc: 0.4247
# 📦 Saved new best model to: c:\Users\DELL\Documents\GitHub\ml-internship-projects\Project_1_Image_Classification_of_Animals_v2\models\resnet18_20250702_155758.pt
#
# 🔁 Epoch 3/20
# Train Loss: 2.1544, Acc: 0.4279
# Val   Loss: 1.9543, Acc: 0.5685
# 📦 Saved new best model to: c:\Users\DELL\Documents\GitHub\ml-internship-projects\Project_1_Image_Classification_of_Animals_v2\models\resnet18_20250702_155758.pt
#
# 🔁 Epoch 4/20
# Train Loss: 1.9467, Acc: 0.5632
# Val   Loss: 1.7454, Acc: 0.6747
# 📦 Saved new best model to: c:\Users\DELL\Documents\GitHub\ml-internship-projects\Project_1_Image_Classification_of_Animals_v2\models\resnet18_20250702_155758.pt
#
# ...

# %%
import matplotlib.pyplot as plt

# === Raw Values === #
epochs = list(range(1, 21))

val_loss = [
    2.4559, 2.1921, 1.9543, 1.7454, 1.5595, 1.4092, 1.2602, 1.1579, 1.0525, 0.9664,
    0.9100, 0.8267, 0.7784, 0.7361, 0.6848, 0.6557, 0.6106, 0.5837, 0.5648, 0.5321
]

val_acc = [
    0.2397, 0.4247, 0.5685, 0.6747, 0.7534, 0.7842, 0.8116, 0.8356, 0.8664, 0.8767,
    0.8836, 0.8870, 0.8973, 0.8973, 0.9007, 0.9075, 0.9178, 0.9384, 0.9315, 0.9247
]

train_loss = [
    2.6783, 2.3913, 2.1544, 1.9467, 1.7477, 1.5800, 1.4202, 1.3056, 1.1988, 1.1116,
    1.0367, 0.9628, 0.8992, 0.8512, 0.8010, 0.7732, 0.7281, 0.7024, 0.6602, 0.6168
]

train_acc = [
    0.1088, 0.2934, 0.4279, 0.5632, 0.6809, 0.7360, 0.7956, 0.8272, 0.8324, 0.8529,
    0.8654, 0.8765, 0.8890, 0.8801, 0.9037, 0.8956, 0.9110, 0.9029, 0.9154, 0.9206
]

# === Plot === #
plt.figure(figsize=(14, 6))

# Loss Curve
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'o-', label='Train Loss', color='steelblue')
plt.plot(epochs, val_loss, 'o-', label='Val Loss', color='orange')
plt.title("📉 Loss per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.legend()

# Accuracy Curve
plt.subplot(1, 2, 2)
plt.plot(epochs, train_acc, 'o-', label='Train Acc', color='seagreen')
plt.plot(epochs, val_acc, 'o-', label='Val Acc', color='darkred')
plt.title("📈 Accuracy per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_26024\2143623462.py:49: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\DELL\AppData\Local\Temp\ipykernel_26024\2143623462.py:49: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\DELL\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\DELL\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
